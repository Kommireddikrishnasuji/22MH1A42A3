# %% [markdown]
# <a href="https://colab.research.google.com/github/Kommireddikrishnasuji/22MH1A42A3/blob/main/ml2.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd
import numpy as np

# %%
data=pd.read_csv("/content/heart.CSV.csv")
data
# Out:
#       age  sex  cp  trestbps  chol  fbs  restecg  thalach  exang  oldpeak  \
# 0      52    1   0       125   212    0        1      168      0      1.0
# 1      53    1   0       140   203    1        0      155      1      3.1
# 2      70    1   0       145   174    0        1      125      1      2.6
# 3      61    1   0       148   203    0        1      161      0      0.0
# 4      62    0   0       138   294    1        1      106      0      1.9
# ...   ...  ...  ..       ...   ...  ...      ...      ...    ...      ...
# 1020   59    1   1       140   221    0        1      164      1      0.0
# 1021   60    1   0       125   258    0        0      141      1      2.8
# 1022   47    1   0       110   275    0        0      118      1      1.0
# 1023   50    0   0       110   254    0        0      159      0      0.0
# 1024   54    1   0       120   188    0        1      113      0      1.4
#
#       slope  ca  thal  target
# 0         2   2     3       0
# ...

# %%
from sklearn.preprocessing import LabelEncoder
from sklearn.preprocessing import OrdinalEncoder
le=LabelEncoder()
oe=OrdinalEncoder()
y=data.iloc[:,-1]
x=data.iloc[:,:-1]
y
x
# Out:
#       age  sex  cp  trestbps  chol  fbs  restecg  thalach  exang  oldpeak  \
# 0      52    1   0       125   212    0        1      168      0      1.0
# 1      53    1   0       140   203    1        0      155      1      3.1
# 2      70    1   0       145   174    0        1      125      1      2.6
# 3      61    1   0       148   203    0        1      161      0      0.0
# 4      62    0   0       138   294    1        1      106      0      1.9
# ...   ...  ...  ..       ...   ...  ...      ...      ...    ...      ...
# 1020   59    1   1       140   221    0        1      164      1      0.0
# 1021   60    1   0       125   258    0        0      141      1      2.8
# 1022   47    1   0       110   275    0        0      118      1      1.0
# 1023   50    0   0       110   254    0        0      159      0      0.0
# 1024   54    1   0       120   188    0        1      113      0      1.4
#
#       slope  ca  thal
# 0         2   2     3
# 1         0   0     3
# ...

# %%
x
# Out:
# array([[0.45      , 1.        , 0.        , ..., 1.        , 0.5       ,
#         1.        ],
#        [0.475     , 1.        , 0.        , ..., 0.        , 0.        ,
#         1.        ],
#        [0.9       , 1.        , 0.        , ..., 0.        , 0.        ,
#         1.        ],
#        ...,
#        [0.325     , 1.        , 0.        , ..., 0.5       , 0.25      ,
#         0.66666667],
#        [0.4       , 0.        , 0.        , ..., 1.        , 0.        ,
#         0.66666667],
#        [0.5       , 1.        , 0.        , ..., 0.5       , 0.25      ,
#         1.        ]])

# %%
x=oe.fit_transform(x)
y=le.fit_transform(y)
x=oe.fit_transform(x)
y=le.fit_transform(y)
from sklearn.preprocessing import MinMaxScaler
mms=MinMaxScaler()

x=mms.fit_transform(x)

y=mms.fit_transform(y)
from sklearn.model_selection import train_test_split
x_train,x_test,y_test=train_test_split(x,y,train_size=0.8,random_state=16)
from sklearn.svm import SVC
svm=SVC(kernel='linear')
svm.fit(x_train, y_train)
pred=svm.predit(x_test)
from sklearn.metrics import accuracy_score
accuracy_score(y_test,pred)
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-33-1be477a67c96> in <cell line: 10>()
#       8 x=mms.fit_transform(x)
#       9
# ---> 10 y=mms.fit_transform(y)
#      11 from sklearn.model_selection import train_test_split
#      12 x_train,x_test,y_test=train_test_split(x,y,train_size=0.8,random_state=16)
#
# /usr/local/lib/python3.10/dist-packages/sklearn/utils/_set_output.py in wrapped(self, X, *args, **kwargs)
#     138     @wraps(f)
#     139     def wrapped(self, X, *args, **kwargs):
# --> 140         data_to_wrap = f(self, X, *args, **kwargs)
#     141         if isinstance(data_to_wrap, tuple):
#     142             # only wrap the first output for cross decomposition
#
# /usr/local/lib/python3.10/dist-packages/sklearn/base.py in fit_transform(self, X, y, **fit_params)
#     876         if y is None:
# ...

# %%
x=oe.fit_transform(x)
y=le.fit_transform(y)
# Out:
# /usr/local/lib/python3.10/dist-packages/sklearn/preprocessing/_label.py:116: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)

# %%
x=oe.fit_transform(x)
y=le.fit_transform(y)

# %%
from sklearn.preprocessing import LabelEncoder

# %%
from sklearn.preprocessing import OrdinalEncoder

# %%
y=data.iloc[:,-1]
x=data.iloc[:,:-1]

# %%
y
# Out:
# 0       0
# 1       0
# 2       0
# 3       0
# 4       0
#        ..
# 1020    1
# 1021    0
# 1022    0
# 1023    1
# 1024    0
# Name: target, Length: 1025, dtype: int64

# %%
x=oe.fit_transform(x)

# %%
y=le.fit_transform(y)

# %%
from sklearn.preprocessing import MinMaxScaler

# %%
mms=MinMaxScaler()

# %%
x=mms.fit_transform(x)

# %%
y=pd.DataFrame(y)

# %%
from sklearn.model_selection import train_test_split

# %%
x_train,x_test,y_train,y_test=train_test_split(x,y,train_size=0.8,random_state=16)

# %%
from sklearn.svm import SVC

# %%
svs=SVC(kernel='linear')

# %%
svm.fit(x_train,y_train)
# Out:
# /usr/local/lib/python3.10/dist-packages/sklearn/utils/validation.py:1143: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# SVC(kernel='linear')

# %%
pred=svm.predict(x_test)

# %%
from sklearn.metrics import accuracy_score

# %%
accuracy_score(y_test,pred)
# Out:
# 0.8341463414634146
